# %% [markdown]
# <a href="https://colab.research.google.com/github/25pa1a4516-ui/program-1/blob/main/Exercise_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = int(input("enter : "))
b = int(input("enter : "))
# Out:
# enter : 8
# enter : 9

# %%
# ARITHMETIC OPERATORS
print(a+b)
print(b-a)
print(a*b)
print(b/a)
print(a%b)
print(b//a)
print(a**b)
# Out:
# 17
# 1
# 72
# 1.125
# 8
# 1
# 134217728

# %%
#logical operators
print(a==5 and b==17)
print(b==6 or a==10)
print(not(a==5 and b==17))
# Out:
# False
# False
# True

# %%
#comparision operators
print(a>b)
print(a<b)
print(a<=b)
print(a>=b)
print(a==b)
print(a!=b)
# Out:
# False
# True
# True
# False
# False
# True
